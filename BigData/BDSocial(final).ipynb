# %%
# %matplotlib inline
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

plt.rcParams["figure.figsize"] = (20, 10)

# %%
iris = pd.read_csv('iris.csv')

# %%
print(iris.shape)
# Out:
# (150, 5)

# %%
iris.head(5)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.tail(5)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
G = nx.from_pandas_edgelist(iris,
                            source='sepal.length',
                            target='petal.length',
                            create_using=nx.DiGraph())

# %%
print(G)
# Out:
# DiGraph with 54 nodes and 123 edges

# %%
nx.draw_networkx(G)

# %%
plt.hist(dict(G.degree()).values())
# Out:
# (array([17.,  9.,  3.,  4.,  6.,  2.,  8.,  2.,  1.,  2.]),
#  array([ 1. ,  2.1,  3.2,  4.3,  5.4,  6.5,  7.6,  8.7,  9.8, 10.9, 12. ]),
#  <BarContainer object of 10 artists>)

# %%
h = plt.hist(dict(G.in_degree(weight='points')).values())

# %%
degree_centrality = nx.degree_centrality(G)
degree_centralities = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)
for node, centrality in degree_centralities:
  print(f"Node: {node} Centrality: {centrality}")
# Out:
# Node: 5.1 Centrality: 0.22641509433962265
# Node: 5.0 Centrality: 0.20754716981132074
# Node: 5.6 Centrality: 0.18867924528301885
# Node: 5.7 Centrality: 0.16981132075471697
# Node: 5.5 Centrality: 0.16981132075471697
# Node: 1.4 Centrality: 0.1509433962264151
# Node: 4.9 Centrality: 0.1509433962264151
# Node: 1.5 Centrality: 0.1509433962264151
# Node: 5.8 Centrality: 0.1509433962264151
# Node: 4.5 Centrality: 0.1509433962264151
# Node: 6.3 Centrality: 0.1509433962264151
# Node: 6.1 Centrality: 0.1509433962264151
# Node: 6.7 Centrality: 0.1509433962264151
# Node: 4.8 Centrality: 0.1320754716981132
# Node: 6.0 Centrality: 0.1320754716981132
# Node: 4.7 Centrality: 0.11320754716981132
# Node: 1.3 Centrality: 0.11320754716981132
# Node: 4.6 Centrality: 0.11320754716981132
# Node: 5.4 Centrality: 0.11320754716981132
# Node: 4.4 Centrality: 0.11320754716981132
# Node: 6.4 Centrality: 0.11320754716981132
# Node: 5.2 Centrality: 0.09433962264150943
# Node: 6.9 Centrality: 0.09433962264150943
# Node: 6.5 Centrality: 0.09433962264150943
# Node: 5.9 Centrality: 0.09433962264150943
# Node: 1.6 Centrality: 0.07547169811320754
# Node: 4.0 Centrality: 0.07547169811320754
# Node: 6.2 Centrality: 0.07547169811320754
# Node: 1.7 Centrality: 0.05660377358490566
# Node: 4.3 Centrality: 0.05660377358490566
# Node: 6.6 Centrality: 0.05660377358490566
# Node: 3.9 Centrality: 0.05660377358490566
# Node: 4.2 Centrality: 0.05660377358490566
# Node: 4.1 Centrality: 0.05660377358490566
# Node: 6.8 Centrality: 0.05660377358490566
# Node: 7.2 Centrality: 0.05660377358490566
# Node: 7.7 Centrality: 0.05660377358490566
# Node: 1.2 Centrality: 0.03773584905660377
# Node: 1.9 Centrality: 0.03773584905660377
# Node: 5.3 Centrality: 0.03773584905660377
# Node: 3.3 Centrality: 0.03773584905660377
# Node: 3.5 Centrality: 0.03773584905660377
# Node: 1.1 Centrality: 0.018867924528301886
# Node: 1.0 Centrality: 0.018867924528301886
# Node: 7.0 Centrality: 0.018867924528301886
# Node: 3.6 Centrality: 0.018867924528301886
# Node: 3.8 Centrality: 0.018867924528301886
# Node: 3.7 Centrality: 0.018867924528301886
# Node: 3.0 Centrality: 0.018867924528301886
# Node: 7.1 Centrality: 0.018867924528301886
# Node: 7.6 Centrality: 0.018867924528301886
# Node: 7.3 Centrality: 0.018867924528301886
# Node: 7.4 Centrality: 0.018867924528301886
# Node: 7.9 Centrality: 0.018867924528301886

# %%
betweenness_centrality = nx.betweenness_centrality(G)
print(betweenness_centrality)

top_5_betweenness_centrality = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)[:5]

print("Top 5 nodes by betweenness centrality:")
for node, centrality in top_5_betweenness_centrality:
    print(f"Centrality: {node}")
# Out:
# {5.1: 0.016952334876863175, 1.4: 0.0, 4.9: 0.006256767341673002, 4.7: 0.003483309143686502, 1.3: 0.0, 4.6: 0.004790989932499366, 1.5: 0.0, 5.0: 0.009229790126016543, 5.4: 0.0018579952542216692, 1.7: 0.0, 4.4: 0.0018781532932476326, 4.8: 0.003761490082244799, 1.6: 0.0, 4.3: 0.0010885341074020319, 1.1: 0.0, 5.8: 0.005388243831640057, 1.2: 0.0, 5.7: 0.004230020503605408, 1.0: 0.0, 1.9: 0.0, 5.2: 0.0009387886746377312, 5.5: 0.007710449927431059, 4.5: 0.0017537493952588291, 5.3: 0.000725689404934688, 7.0: 0.0, 6.4: 0.006894049346879536, 6.9: 0.0030752528394037827, 4.0: 0.0, 6.5: 0.0, 6.3: 0.008708272859216255, 3.3: 0.0, 6.6: 0.0021770682148040637, 3.9: 0.0, 3.5: 0.0, 5.9: 0.0050798258345428155, 4.2: 0.0, 6.0: 0.005019351717464926, 6.1: 0.011747817172345474, 5.6: 0.013795010021425115, 3.6: 0.0, 6.7: 0.004443983689266707, 4.1: 0.0, 6.2: 0.0, 6.8: 0.0, 3.8: 0.0, 3.7: 0.0, 3.0: 0.0, 7.1: 0.0, 7.6: 0.0, 7.3: 0.0, 7.2: 0.0, 7.7: 0.0, 7.4: 0.0, 7.9: 0.0}
# Top 5 nodes by betweenness centrality:
# Centrality: 5.1
# Centrality: 5.6
# Centrality: 6.1
# Centrality: 5.0
# Centrality: 6.3
